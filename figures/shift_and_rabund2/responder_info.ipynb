# %%
from IPython.display import FileLink

# %%
# %load_ext rmagic
# Out:
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic

# %%
# %%R
# library(DESeq2)
# library(phyloseq)
# library(plyr)
# library(ggplot2)
# library(doParallel)
# library(foreach)
# library(reshape)
# library(RColorBrewer)
# library(gridExtra)
# library(stats)

# %%
# %%R
#
# asNumeric = function(x) { as.numeric(as.character(x)) }
#
# physeq = import_biom("../data/otu_table_wtax.biom", "../data/otusn.tree")
# sample.data = import_qiime_sample_data("../data/ABCD_combined_reads_mapper.tsv")
# sample.data$Density = asNumeric(sample.data$Density)
# physeq = merge_phyloseq(physeq,sample.data)
# physeq.md = sample_data(physeq)
# physeq.bulk = prune_samples(row.names(physeq.md) %in% grep("bulk",
#                                                            row.names(physeq.md),
#                                                            value=TRUE), physeq)
# physeq.bulk = transform_sample_counts(physeq.bulk, function(x) x/sum(x))
# bulk.mdf = psmelt(physeq.bulk)

# %%
# %%R
# RA.df = ddply(bulk.mdf, .(OTU),
#         summarize,
#         mean.abund = mean(Abundance),
#         max.abund = max(Abundance),
#         min.abund = min(Abundance))

# %%
# %%R -h 350
# RA.df.sorted = RA.df[order(-RA.df$mean.abund, -RA.df$max.abund),]
# RA.df.sorted$Rank = 1:nrow(RA.df.sorted)
#
# p = ggplot(RA.df.sorted, aes(y = mean.abund, x = Rank))
# p = p + geom_ribbon(aes(ymax = max.abund, ymin = min.abund), alpha = 0.25)
# p = p + geom_line()
# p = p + scale_y_log10()
# p = p + labs(y = "Relative Abundance")
#
# p

# %%
# %%R
#
# density.min = 1.7125
# density.max = 1.755
# l2fc.threshold = 0.75
# sparsity_threshold = 0.60
#
# get_Ps = function(physeq.obj) {
#     dds = phyloseq_to_deseq2(physeq.obj, ~Treatment)
#     dds = DESeq(dds, quiet = TRUE, fitType = "local")
#     theta = l2fc.threshold
#     r = results(dds, independentFiltering = FALSE)
#     beta = r$log2FoldChange
#     betaSE = r$lfcSE
#     p = pnorm(beta, theta, betaSE, lower.tail = FALSE)
#     r$p = p
#     return(r[, c("log2FoldChange", "p")])
# }
#
# deseq_prune = function(physeq.obj, treatment, day, sparsity_threshold) {
#     physeq.md = sample_data(physeq.obj)
#     p = prune_samples((physeq.md$Treatment %in% c("12CCPS",treatment))&
#                       (physeq.md$Day == day)&
#                       !(row.names(physeq.md) %in% grep("bulk", row.names(physeq.md), value=TRUE))&
#                       (physeq.md$Density >= density.min)&
#                       (physeq.md$Density <= density.max), physeq)
#     p.thresh = filter_taxa(p, function(x) sum(x > 0) > (sparsity_threshold * length(x)), TRUE)
#     return(p.thresh)
# }

# %%
# %%R
#
# treatments = c("13CCPS", "13CXPS")
#
# df_all = data.frame()
#
# for (treatment in treatments) {
#     if (treatment == "13CCPS") {
#         days = c(3, 7, 14, 30)
#     } else if (treatment == "13CXPS") {
#         days = c(1, 3, 7, 14, 30)
#     }
#
#     df_treatment = data.frame()
#
#     for (day in days) {
#         DF = NULL
#         physeq.treatment = deseq_prune(physeq, treatment, day, sparsity_threshold)
#         DF = get_Ps(physeq.treatment)
#         supp = tax_table(physeq.treatment)
#         if (!setequal(row.names(DF), row.names(supp))) {
#             stop("Ordination and supplementary data indices differ on the following:\n.",
#             setdiff(row.names(DF), row.names(supp)))
#         }
#         DF = data.frame(DF, supp)
#         DF$OTU = rownames(DF)
#         DF$Day = day
#         df_treatment = rbind(df_treatment, DF)
#     }
#     df_treatment$Treatment = treatment
#     df_all = rbind(df_all, df_treatment)
# }

# %%
# %%R -h 400 -w 700
#
# colours = c("#377eb8", "#4daf4a")
# getPalette = colorRampPalette(brewer.pal(8, "Set1"))
#
# FDR = 0.10
#
# tax = data.frame(tax_table(physeq.bulk))
# tax$OTU = rownames(tax)
#
# df_all$p.adj = p.adjust(df_all$p, method = "BH")
#
# OTUs.wP = unique(df_all$OTU)
#
# RA.df.wP = subset(RA.df, OTU %in% OTUs.wP)
#
# RA.df.wP.sorted = RA.df.wP[order(-RA.df.wP$mean.abund, -RA.df.wP$max.abund),]
# RA.df.wP.sorted$Rank = 1:nrow(RA.df.wP.sorted)
#
# df_all.p.summarize = ddply(df_all, .(OTU, Treatment), summarize, p.adj.min = min(p.adj))
# df_all.p.summarize = merge_recurse(list(df_all.p.summarize, RA.df.wP.sorted), by = "OTU")
# df_all.p.summarize = merge_recurse(list(df_all.p.summarize, tax), by = "OTU")
#
# #d = RA.df.wP.sorted
# d = df_all.p.summarize
# d$jitter = 1 + runif(nrow(d), min = 0.25, max = 2.5)
#
# p = ggplot(d, aes(y = mean.abund, x = Rank))
# p = p + geom_ribbon(aes(ymax = max.abund, ymin = min.abund), alpha = 0.25)
#
# p = p + geom_segment(data = subset(d, (p.adj.min <= FDR)&(Treatment=="13CXPS")),
#                      size = 1.5,
#                      aes(xend = Rank, yend = mean.abund * jitter * 0.2, color = Treatment))
# p = p + geom_segment(data = subset(d, (p.adj.min <= FDR)&(Treatment=="13CCPS")),
#                      size = 1.5,
#                      aes(xend = Rank, yend = mean.abund * jitter, color = Treatment))
#
# p = p + geom_point(data = subset(d, (p.adj.min <= FDR)&(Treatment=="13CCPS")),
#                    shape = 21,
#                    size = 2.5,
#                    alpha = 1.0,
#                    aes(y = mean.abund * jitter, fill = Rank2))
# p = p + geom_point(data = subset(d, (p.adj.min <= FDR)&(Treatment=="13CXPS")),
#                    shape = 21,
#                    size = 2.5,
#                    alpha = 1.0,
#                    aes(y = mean.abund * jitter * 0.2, fill = Rank2))
#
# p = p + geom_line(size = 1)
#
# p = p + scale_fill_manual(values=getPalette(8), labels = t)
#
# p = p + scale_color_manual(values=colours)
#
# p = p + scale_y_log10()
# p = p + labs(y = "Relative Abundance", fill = "Phylum")
#
# p = p + theme_bw()
#
# p = p + guides(fill = guide_legend(label.hjust = 0))
#
# p.rabund = p
#
# p

# %%
# %%R
# ds = subset(d, (p.adj.min <= FDR))
# p = as.character(levels(factor(ds$Rank2)))
# quote(paste("italic(", p, ")", sep=""))
# Out:
# [1] "italic(Actinobacteria)"  "italic(Bacteroidetes)"
# [3] "italic(Chloroflexi)"     "italic(Cyanobacteria)"
# [5] "italic(Firmicutes)"      "italic(Planctomycetes)"
# [7] "italic(Proteobacteria)"  "italic(Verrucomicrobia)"

# %%
# %%R
# t = parse(text = paste("italic(", p, ")", sep=""))

# %%
# %%R
# cellulose.mean_abund = subset(df_all.p.summarize, (p.adj.min <= FDR)&(Treatment=="13CCPS"))$mean.abund
# xylose.mean_abund = subset(df_all.p.summarize, (p.adj.min <= FDR)&(Treatment=="13CXPS"))$mean.abund
#
# wilcox.test(xylose.mean_abund, cellulose.mean_abund, alternative = "greater")
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  xylose.mean_abund and cellulose.mean_abund
# W = 985, p-value = 0.009881
# alternative hypothesis: true location shift is greater than 0

# %%
# %%R
# df.shifts = read.csv("../data/density_shifts.csv", sep = ",", header = TRUE, )
# df.shifts$shift = as.numeric(as.character(df.shifts$shift))
# head(df.shifts)
# Out:
#        OTU        shift Day Treatment
# 1  OTU.759           NA   1    13CXPS
# 2  OTU.758  0.017597635   1    13CXPS
# 3  OTU.757 -0.005009263   1    13CXPS
# 4  OTU.756  0.009056019   1    13CXPS
# 5 OTU.5419 -0.003075774   1    13CXPS
# 6  OTU.839  0.002702782   1    13CXPS

# %%
# %%R -w 400 -h 350
# df_all.wShifts = merge(df_all, df.shifts, by = c("OTU","Day","Treatment"))
#
# df.plot = subset(df_all.wShifts, p.adj <= FDR)
#
# colours = c("#377eb8", "#4daf4a")
#
# p = ggplot(df.plot, aes(x = as.numeric(as.character(shift))))
#
# p = p + geom_density(aes(color = Treatment, fill = Treatment), alpha = 0.50)
# p = p + geom_rug(aes(color = Treatment))
# p = p + scale_color_manual(values=colours)
# p = p + scale_fill_manual(values=colours)
# p = p + labs(y = "Kernel Density", x = "Density Shift, mg/L")
#
# p = p + guides(color = FALSE, fill = FALSE)
#
# p = p + theme_bw()
#
# p.shift = p
#
# p

# %%
# %%R
# cellulose.shifts = subset(df_all.wShifts, (Treatment == "13CCPS")&(p.adj <= FDR))$shift
# xylose.shifts = subset(df_all.wShifts, (Treatment == "13CXPS")&(p.adj <= FDR))$shift
#
# wilcox.test(cellulose.shifts, xylose.shifts, alternative = "greater")
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  cellulose.shifts and xylose.shifts
# W = 2386, p-value = 1.225e-08
# alternative hypothesis: true location shift is greater than 0

# %%
# %%R -w 1100 -h 350
#
# p.combined = grid.arrange(p.shift, p.rabund, widths = c(1, 2), ncol = 2)
#
# p.combined
# Out:
# NULL

# %%
# %%R
# pdf("../figs/shift_and_rabund.pdf", w = 11, h = 4)
# grid.arrange(p.shift, p.rabund, widths = c(1, 2), ncol = 2)
# dev.off()
# Out:
# png
#   2

# %%
FileLink("../figs/shift_and_rabund.pdf")
# Out:
# /home/chuck/working/succ-C-DNASIP/figs/shift_and_rabund.pdf

# %%
# %%R
# head(df_all)
# Out:
#         log2FoldChange         p    Rank1           Rank2              Rank3
# OTU.79      0.67978568 0.5993647 Bacteria __Bacteroidetes       __Cytophagia
# OTU.50      0.69449438 0.5769320 Bacteria __Bacteroidetes       __Cytophagia
# OTU.12      0.78943950 0.4449446 Bacteria __Bacteroidetes __Sphingobacteriia
# OTU.122     0.05158181 0.9891019 Bacteria __Bacteroidetes __Sphingobacteriia
# OTU.121     0.62035441 0.6698472 Bacteria __Bacteroidetes __Sphingobacteriia
# OTU.155     0.68439199 0.5853871 Bacteria __Bacteroidetes __Sphingobacteriia
#                        Rank4              Rank5             Rank6
# OTU.79        __Cytophagales    __Cytophagaceae     __Flexibacter
# OTU.50        __Cytophagales    __Cytophagaceae     __Flexibacter
# OTU.12  __Sphingobacteriales __Chitinophagaceae      __uncultured
# OTU.122 __Sphingobacteriales __Chitinophagaceae __Ferruginibacter
# OTU.121 __Sphingobacteriales __Chitinophagaceae __Ferruginibacter
# ...

# %%
# %%R
# d = merge(df.shifts, df_all, by = c("OTU", "Day", "Treatment"))
# d = subset(d, (Treatment == "13CXPS")&(p.adj <= FDR))
# d = d[order(-as.numeric(as.character(d$shift))),]
# head(d, 10)
# Out:
#           OTU Day Treatment                shift log2FoldChange            p
# 2197  OTU.369   1    13CXPS  0.02263081622408336       2.852072 8.380398e-08
# 2944 OTU.5284   7    13CXPS 0.022540860420242392       2.117673 3.951550e-04
# 3121   OTU.57  14    13CXPS  0.02198790634614123       2.470783 4.218841e-10
# 1385  OTU.241  14    13CXPS 0.021716187652959462       1.649142 2.077547e-03
# 3122   OTU.57  30    13CXPS 0.021715812851852867       1.692358 1.174723e-03
# 451    OTU.14   1    13CXPS  0.01710538785247473       2.201793 5.177406e-05
# 473    OTU.14   3    13CXPS  0.01614962853233526       3.054204 7.764936e-12
# 3134   OTU.57   7    13CXPS  0.01611557443703049       2.525177 3.014225e-06
# 1411  OTU.244   7    13CXPS 0.014780623268612514       2.017676 1.239675e-03
# 511    OTU.14   7    13CXPS 0.014472848167341734       1.917117 2.497576e-03
#         Rank1             Rank2            Rank3                   Rank4
# ...
